# %%
import matplotlib.pyplot as plt
import os
os.chdir('E:\\PlotDel_Steven\\sen_proj')

# %%
from fpackage.create_mask import CreateMask

# %%
os.getcwd()
# Out:
# 'E:\\PlotDel_Steven\\sen_proj'

# %%
raster_path = '../Data/downloaded.tif'

shape_path = 'Data/sene_poly.geojson'

#instantiate the create mask class
create_mask = CreateMask(raster_path, shape_path)

# Generate Binary maks
mask = create_mask.binarize_raster()

# Plot the mask
plt.figure(figsize=(15,15))
plt.imshow(mask)

# %%
#mask

# %%
#get the boundaries
output_arr = create_mask.get_boundaries(mask, boundary_width=5)
#tune the boundary_width depending on how large or small you want the boundary width in the masks
plt.figure(figsize=(15,15))
plt.imshow(output_arr)

# %%
#get the boundaries
output_arr = create_mask.get_boundaries(mask, boundary_width=10)
#tune the boundary_width depending on how large or small you want the boundary width in the masks
plt.figure(figsize=(15,15))
plt.imshow(output_arr)

# %%
#get the boundaries
output_arr = create_mask.get_boundaries(mask, boundary_width=15)
#tune the boundary_width depending on how large or small you want the boundary width in the masks
plt.figure(figsize=(15,15))
plt.imshow(output_arr)

# %%
#get the boundaries
output_arr = create_mask.get_boundaries(mask, boundary_width=20)
#tune the boundary_width depending on how large or small you want the boundary width in the masks
plt.figure(figsize=(15,15))
plt.imshow(output_arr)

# %%
#get the boundaries
output_arr = create_mask.get_boundaries(mask, boundary_width=30)
#tune the boundary_width depending on how large or small you want the boundary width in the masks
plt.figure(figsize=(15,15))
plt.imshow(output_arr)

# %%
#save mask
out_file="../Data/mask.tif"
create_mask.save_mask(output_arr, out_file)

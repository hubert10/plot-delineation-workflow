# %%
## Imports
import os
import random
import numpy as np
import cv2
import pathlib
import matplotlib.pyplot as plt

import tensorflow as tf
## Seeding 
seed = 2019
random.seed = seed
np.random.seed = seed
tf.seed = seed
# %matplotlib inline
#The line above is necesary to show Matplotlib's plots inside a Jupyter Notebook

# %%
os.chdir('E:\\PlotDel_Steven\\sen_proj')
from fpackage.resnet50_unet import DataGen, build_resnet50_unet

# %% [markdown]
# **Path**

# %%
data_dir= "../"

# %%
dataset_path = data_dir + "Data/dataset"

# %% [markdown]
# **Hyperparameters**

# %%
image_size = 512
batch_size = 8

# %% [markdown]
# ## Get the ResNet50 model

# %% [markdown]
# **RESNET-UNET**

# %%
input_shape = (512, 512, 3)
model = build_resnet50_unet(input_shape)
model.summary()
# Out:
# Model: "ResNet50_U-Net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 512, 512, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 518, 518, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 256, 256, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 256, 256, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 256, 256, 64) 0           conv1_bn[0][0]
# ...

# %% [markdown]
# # **Test the model on unseen data**

# %% [markdown]
# **Load weights**

# %%
model.load_weights(dataset_path + "/ResNet_UNet.h5")

# %%
#predict on entire dataset and save model 
import pathlib
test_dir = "../Data"
test_dir = pathlib.Path(test_dir)
images = list(test_dir.glob('tiles_res_images/*'))

# function to predict and save images
def pred_and_save_image(input_img, save_path, idx):
    try:
        image = cv2.imread(str(input_img))
    except:
        image = io.imread(str(input_img), as_gray = True)
    image = cv2.resize(image, (image_size, image_size))
    image = np.expand_dims(image, axis=0) #very important
    image = image/255.0
    image = np.array(image)
    #print(image.shape)
    result = model.predict(image)
    #print(result)
    result = result > 0.20
    #print(result)
    result = np.reshape(result*255, (image_size, image_size))
    #save a image using the iteration index
    cv2.imwrite(save_path+"/predicted_{}_{}.png".format(idx, idx),result)
    #return

for idx, val in enumerate(images):
    print(val)
    pred_and_save_image(str(val), dataset_path+"/f_predicted", idx)
# Out:
# ..\Data\tiles_res_images\tile_0-0.png
# ..\Data\tiles_res_images\tile_0-1024.png
# ..\Data\tiles_res_images\tile_0-10240.png
# ..\Data\tiles_res_images\tile_0-10496.png
# ..\Data\tiles_res_images\tile_0-10752.png
# ..\Data\tiles_res_images\tile_0-11008.png
# ..\Data\tiles_res_images\tile_0-11264.png
# ..\Data\tiles_res_images\tile_0-11520.png
# ..\Data\tiles_res_images\tile_0-1280.png
# ..\Data\tiles_res_images\tile_0-1536.png
# ..\Data\tiles_res_images\tile_0-1792.png
# ..\Data\tiles_res_images\tile_0-2048.png
# ..\Data\tiles_res_images\tile_0-2304.png
# ..\Data\tiles_res_images\tile_0-256.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-f1fec33d7943> in <module>
#      27 for idx, val in enumerate(images):
#      28     print(val)
# ---> 29     pred_and_save_image(str(val), dataset_path+"/f_predicted", idx)
#
# ...

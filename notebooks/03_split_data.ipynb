# %%
import os
os.chdir('E:\\PlotDel_Steven\\sen_proj')
data_dir= "../"

# %% [markdown]
# # **Google Images**
#
#
# In the first step, we will first convert the geojson to mask and later on cut the google image and the mask images in to tiles of dimension (256,256).

# %%
from fpackage.split_data import SplitData

# %% [markdown]
# In the following line you will cut the google images and later the mask created from the geojson

# %%
##mask tiling
#rasterized

in_path = data_dir+'Data/'         #input path
input_filename = 'mask.tif'    #image name

out_path = data_dir+'Data/tiles_res_masked'    #output folder
output_filename = 'tile_{}-{}.png'   #tiles_name


tiles_width = 256
tiles_height = 256

splitdata = SplitData(in_path, input_filename, out_path, output_filename, tiles_width, tiles_height)

splitdata.split()
# Out:
# Window(col_off=0, row_off=0, width=256, height=256)
# Window(col_off=0, row_off=256, width=256, height=256)
# Window(col_off=0, row_off=512, width=256, height=256)
# Window(col_off=0, row_off=768, width=256, height=256)
# Window(col_off=0, row_off=1024, width=256, height=256)
# Window(col_off=0, row_off=1280, width=256, height=256)
# Window(col_off=0, row_off=1536, width=256, height=256)
# Window(col_off=0, row_off=1792, width=256, height=256)
# Window(col_off=0, row_off=2048, width=256, height=256)
# Window(col_off=0, row_off=2304, width=256, height=256)
# Window(col_off=0, row_off=2560, width=256, height=256)
# Window(col_off=0, row_off=2816, width=256, height=256)
# Window(col_off=0, row_off=3072, width=256, height=256)
# Window(col_off=0, row_off=3328, width=256, height=256)
# Window(col_off=0, row_off=3584, width=256, height=256)
# Window(col_off=0, row_off=3840, width=256, height=256)
# Window(col_off=0, row_off=4096, width=256, height=256)
# ...

# %%
##Images tiling
#Original256

in_path = data_dir+'Data/'         #input path
input_filename = 'downloaded.tif'    #image name

out_path = data_dir+'Data/tiles_res_images'    #output folder
output_filename = 'tile_{}-{}.png'   #tiles_name


tiles_width = 256
tiles_height = 256

splitdata = SplitData(in_path, input_filename, out_path, output_filename, tiles_width, tiles_height)

splitdata.split()
# Out:
# Window(col_off=0, row_off=0, width=256, height=256)
# Window(col_off=0, row_off=256, width=256, height=256)
# Window(col_off=0, row_off=512, width=256, height=256)
# Window(col_off=0, row_off=768, width=256, height=256)
# Window(col_off=0, row_off=1024, width=256, height=256)
# Window(col_off=0, row_off=1280, width=256, height=256)
# Window(col_off=0, row_off=1536, width=256, height=256)
# Window(col_off=0, row_off=1792, width=256, height=256)
# Window(col_off=0, row_off=2048, width=256, height=256)
# Window(col_off=0, row_off=2304, width=256, height=256)
# Window(col_off=0, row_off=2560, width=256, height=256)
# Window(col_off=0, row_off=2816, width=256, height=256)
# Window(col_off=0, row_off=3072, width=256, height=256)
# Window(col_off=0, row_off=3328, width=256, height=256)
# Window(col_off=0, row_off=3584, width=256, height=256)
# Window(col_off=0, row_off=3840, width=256, height=256)
# Window(col_off=0, row_off=4096, width=256, height=256)
# ...
